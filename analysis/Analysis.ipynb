# %% [markdown]
# **<h1> Task 5: Analysis**

# %% [markdown]
# **<h2>Research Questions</h2>**

# %% [markdown]
# 1) Which variable has the strongest impact on the overall perceived quality of white wine?
#
# 2) How strong is the correlation between the chosen variable and wine quality in comparison to weaker correlated variables?

# %% [markdown]
# **<h2>Graphs For Analysis from EDA</h2>**

# %%
#To see correlation between alcohol and quality
sns.lineplot(data = df,
             y = 'quality',x = 'alcohol').set_title("Quality vs alcohol graph")
# Out:
# Text(0.5, 1.0, 'Quality vs alcohol graph')

# %%
sns.lineplot(data = df, x = 'fixed acidity',y='quality').set_title("Quality vs Acidity plot")
# Out:
# Text(0.5, 1.0, 'Quality vs Acidity plot')

# %%
sns.lineplot(data = df,
             y = 'quality',x = 'total SO2').set_title("Quality vs total SO2 graph")
# Out:
# Text(0.5, 1.0, 'Quality vs total SO2 graph')

# %%
sns.countplot(data = df,
             y = 'quality',
             palette='colorblind',
             hue = 'alcohol').set_title("The quality of wine split by alcohol percentage")
# Out:
# Text(0.5, 1.0, 'The quality of wine split by alcohol percentage')

# %%
sns.countplot(data = df,
             y = 'quality',
             palette='dark',
             hue = 'fixed acidity').set_title("Counts of wine quality classified by fixed percentage")
# Out:
# Text(0.5, 1.0, 'Counts of wine quality classified by fixed percentage')

# %%
sns.displot(data = df,
             y = 'quality',
             palette='dark',
             hue = 'fixed acidity')

# %% [markdown]
# **Group Wine Quality by variable graph**

# %%
quality
# Out:
#    quality    alcohol  fixed acidity   total SO2
# 0        5   9.666667       6.838384  161.448934
# 1        6  10.392477       6.800213  144.734209
# 2        7  11.316609       6.798097  130.010381
# 3        8  11.472000       6.731200  129.816000
# 4        9  13.000000       7.000000  116.000000

# %%
fig,ax = plt.subplots()
fig.set_size_inches(20,5)
sns.violinplot(data = df,
              x = 'quality',
              y = 'alcohol').set_title("Quality vs alcohol violin plot")
# Out:
# Text(0.5, 1.0, 'Quality vs alcohol violin plot')

# %% [markdown]
# **<h2>Observations and Analysis</h2>**

# %% [markdown]
# Based on the plots and graphs, there is a positive correlation between alcohol and wine quality. If we look at the line plot, as alcohol percentage increases, so does the wine quality. Moreover, if we compare the colors of the bars in each quality(from the countplot), we can see that as the wine quality increases, the colors start to shift towards the higher alcohol percentage's colors. While there are some lower alcohol percentages at those high wine quality ranges, the count is very low , so we can consider it as outliers that have not been caught. The higher alcohol percentages have higher counts in higher wine quality values, which indicates that there indeed is a positive correlation between alcohol percentage and wine quality. Therefore, the plot above has shown that alcohol percentage does play a big part into determining the quality of the wine.
#
# Although the correlations we see between the variables and the quality did not show strong correlation, certain variables do show unique graphs. For example, in the graphs between pH vs quality and sulphates vs quality, the quality is almost constant throughout the graph so it will not be a very important variable towards the quality of the wine. However, we do see a stronger correlation in two graphs that shows a positive and a negative correlation between the variable and the quality of the wine. Those two variables are alcohol(mentioned before) and fixed acidity. We can see that those two variables have the greatest effect on the quality of wine so they are the most important variable when trying to detemrine the white wine's quality.
#
# Focusing more on fixed acidity, we can see that as fixed acidity increases, the wine quality decreases. Looking at the lineplot, while there are some outliers, we can still see that there is an inverse(negative) correlation. Thus, this is another variable besides alcohol that is a big contributor to the quality of the wine. Similar to alcohol, we can see that as the quality of wine increases, the colors from the countplot seem to shift towards lower fixed acidity. When we remove outliers, we can see that there is indeed an obvious inverse correlation between wine quality and fixed acidity. This proves that the fixed acidity variable plays an important role in determining the quality of the wine. It is difficult to see the correlation if you look at the countplot and displot first before looking at the lineplot, but after seeing the lineplot, a correlation will be quite obvious.
#
# Looking at the graph between SO2 and the quality of white wine, we can also see a negative correlation when the amount of sulfur dioxide makes sense (not too little or too much) and even though the graph is similar to fixed acidity where there are certain outliers, we can still see the correlation of each variables through the line plot which is the easiest to see when determining correlation of each variables to the quality. Additionally, in the groupby table, we can also see a negative correlation between the two variables which shows that the SO2 can be seen as an important variable for determining the quality of white wine.
#
# Furthermore, in the table where we group by quality, we can see the correlations that was explained in the paragraphs before from the mean of the values from the variables. Although, the fixed acidity vs quality data did not show a clear positive correlation, the alcohol, which is known to be the most influential variable to the quality, has a clear positive correlation. Also, we can also see a negative correlation in total SO2 vs. quality. Finally, in the violinplot between alcohol and quality, the population of higher quality wine increases as the alcohol percentage increases.

# %% [markdown]
# **<h2>Conclusion</h2>**

# %% [markdown]
# In conclusion, we have found that there are 3 main variables that have a strong correlation to the perceived quality of white wine and we have therefore answered our research questions(written above in the research question section). Firstly, we found that as alcohol percentage increases, the quality of the white wine also increases which proves our conclusion that alcohol has a positive correlation with the quality. This could be due to how the alcohol content affects the wine's body. A higher alcohol content is usually associated with a richer and fuller texture, which is why it could be seen as higher quality. Secondly, we conclude that fixed acidity has negative correlation with the quality of white wine as the lower the fixed acidity, the higher the quality of white wine. Finally, the third variable that affects the quality of white wine is SO2, which has a negative correlation to the quality of white wine
#
# However, even though we can conclude that there are certain correlation associated between the some variables and the quality of wine, we cannot directly conclude that these variables cause the quality to rise since correlation does not explicitly mean causation. So more research and trial and error would be needed so that the quality of wine can always be improved for customer satisfaction. We believe that there isn't a single variable that affects the quality of the wine, but that they impact the quality more than other variables. A good quality white wine should be a good combination of different variables, which is difficult to find without actually making the wine. Thus, we conclude that there are certain variables(alcohol, fixed acidity and SO2) that impact wine quality more than others.
